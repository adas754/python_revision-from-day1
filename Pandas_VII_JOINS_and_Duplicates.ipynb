# %%
import pandas as pd

# %%
df = pd.read_csv("loandata.csv")
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y
# 4             1.0         Rural           Y

# %%
df['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
df['ApplicantIncome'].quantile(0.96)
# Out:
# 15364.320000000014

# %% [raw]
# < 5500 --> low
# >5500 and <15000 --> medium
# >15000 ---->High

# %% [markdown]
# ##### create a new column based on their income

# %%
new = []
for sal in df['ApplicantIncome']:
    if sal <= 5500:
        new.append("Low")
    elif ((sal > 5500) and (sal <= 15000)):
        new.append("Medium")
    elif sal > 15000:
        new.append("High")

# %%
df['New']=new

# %%
def new_sal(x):
    if x<= 5500:
        return "low"
    elif ((x > 5500) and (x <= 15000)):
        return "Medium"
    elif x>15000:
        return "High"

# %%
df['ApplicantIncome'].apply(new_sal)
# Out:
# 0       low
# 1       low
# 2       low
# 3       low
# 4       low
#        ...
# 609    High
# 610    High
# 611    High
# 612    High
# 613    High
# Name: ApplicantIncome, Length: 614, dtype: object

# %% [markdown]
# ## cut()

# %%
df['ApplicantIncome'].max()
# Out:
# 81000

# %%
df["New"]=pd.cut(df['ApplicantIncome'],bins=[0,5500,15000,81000],labels=["Low","Medium","High"])

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status  New
# 0             1.0         Rural           N  Low
# 1             1.0     Semiurban           Y  Low
# 2             NaN         Urban           N  Low
# 3             1.0         Rural           Y  Low
# 4             1.0         Rural           Y  Low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  New                614 non-null    category
# dtypes: category(1), float64(4), int64(1), object(8)
# memory usage: 63.2+ KB

# %% [markdown]
# ### selcting Datatypes

# %%
df.iloc[:,[0,1,2,3,4,5,11,12]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Loan_ID        614 non-null    object
#  1   Gender         601 non-null    object
#  2   Married        611 non-null    object
#  3   Dependents     599 non-null    object
#  4   Education      614 non-null    object
#  5   Self_Employed  582 non-null    object
#  6   Property_Area  614 non-null    object
#  7   Loan_Status    614 non-null    object
# dtypes: object(8)
# memory usage: 38.5+ KB

# %%
df.iloc[:,[7,8,9,10]]
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 0               1800.0       135.0             360.0             1.0
# 1               2917.0        98.0             360.0             1.0
# 2              41667.0       350.0             180.0             NaN
# 3               3683.0       113.0             480.0             1.0
# 4               5296.0       168.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
# [614 rows x 4 columns]

# %%
df.select_dtypes("object")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#     Property_Area Loan_Status
# 0           Rural           N
# 1       Semiurban           Y
# 2           Urban           N
# 3           Rural           Y
# 4           Rural           Y
# ..            ...         ...
# 609     Semiurban           Y
# 610     Semiurban           Y
# 611         Urban           Y
# 612         Urban           Y
# 613         Rural           N
#
# [614 rows x 8 columns]

# %%
df.select_dtypes("float")
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 0               1800.0       135.0             360.0             1.0
# 1               2917.0        98.0             360.0             1.0
# 2              41667.0       350.0             180.0             NaN
# 3               3683.0       113.0             480.0             1.0
# 4               5296.0       168.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609             4750.0       120.0             360.0             1.0
# 610                0.0       600.0             180.0             0.0
# 611                0.0       700.0             300.0             1.0
# 612                0.0       490.0             180.0             1.0
# 613                0.0       360.0             360.0             0.0
#
# [614 rows x 4 columns]

# %%
df.select_dtypes("int")
# Out:
#      ApplicantIncome
# 0                150
# 1                210
# 2                416
# 3                645
# 4                674
# ..               ...
# 609            39147
# 610            39999
# 611            51763
# 612            63337
# 613            81000
#
# [614 rows x 1 columns]

# %% [markdown]
# ### JOINS

# %%
df1 = pd.DataFrame()

# %%
df1['Names'] = ['Kishore',"Dileep","Sreehari","Upendhar"]
df1['Age'] = [24,22,21,25]
df1['Salary'] = [30000,25000,40000,50000]

# %%
df1
# Out:
#       Names  Age  Salary
# 0   Kishore   24   30000
# 1    Dileep   22   25000
# 2  Sreehari   21   40000
# 3  Upendhar   25   50000

# %%
df2 = pd.DataFrame()

# %%
df2['Names'] = ["Anwesha","Bhavani","Sreehari","Dileep","Druvi"]
df2['Age'] = [23,21,21,22,18]
df2['Salary'] = [40000,35000,30000,25000,30000]

# %%
df2
# Out:
#       Names  Age  Salary
# 0   Anwesha   23   40000
# 1   Bhavani   21   35000
# 2  Sreehari   21   30000
# 3    Dileep   22   25000
# 4     Druvi   18   30000

# %% [markdown]
# ### methods to join multiple dataframes
# - concat()
# - merge()

# %%
# join two datagrames row wise
concat_df = pd.concat([df1,df2],axis=0)
concat_df
# Out:
#       Names  Age  Salary
# 0   Kishore   24   30000
# 1    Dileep   22   25000
# 2  Sreehari   21   40000
# 3  Upendhar   25   50000
# 0   Anwesha   23   40000
# 1   Bhavani   21   35000
# 2  Sreehari   21   30000
# 3    Dileep   22   25000
# 4     Druvi   18   30000

# %%
concat_df.reset_index(drop=True)
# Out:
#       Names  Age  Salary
# 0   Kishore   24   30000
# 1    Dileep   22   25000
# 2  Sreehari   21   40000
# 3  Upendhar   25   50000
# 4   Anwesha   23   40000
# 5   Bhavani   21   35000
# 6  Sreehari   21   30000
# 7    Dileep   22   25000
# 8     Druvi   18   30000

# %%
concat_df.columns
# Out:
# Index(['Names', 'Age', 'Salary'], dtype='object')

# %%
#concat_df['index']

# %%
# concat two dataframe column wise
pd.concat([df1,df2],axis=1)
# Out:
#       Names   Age   Salary     Names  Age  Salary
# 0   Kishore  24.0  30000.0   Anwesha   23   40000
# 1    Dileep  22.0  25000.0   Bhavani   21   35000
# 2  Sreehari  21.0  40000.0  Sreehari   21   30000
# 3  Upendhar  25.0  50000.0    Dileep   22   25000
# 4       NaN   NaN      NaN     Druvi   18   30000

# %% [markdown]
# ## merge()
#
# ![image.png](attachment:image.png)

# %%
pd.merge(df1,df2,how="inner")
# Out:
#     Names  Age  Salary
# 0  Dileep   22   25000

# %%
pd.merge(df1,df2,how="inner",on="Names")
# Out:
#       Names  Age_x  Salary_x  Age_y  Salary_y
# 0    Dileep     22     25000     22     25000
# 1  Sreehari     21     40000     21     30000

# %%
pd.merge(df1,df2,how="inner",on=["Names","Age"])
# Out:
#       Names  Age  Salary_x  Salary_y
# 0    Dileep   22     25000     25000
# 1  Sreehari   21     40000     30000

# %%
# left join
pd.merge(df1,df2,how="left")
# Out:
#       Names  Age  Salary
# 0   Kishore   24   30000
# 1    Dileep   22   25000
# 2  Sreehari   21   40000
# 3  Upendhar   25   50000

# %%
# Right join
pd.merge(df1,df2,how="right")
# Out:
#       Names  Age  Salary
# 0   Anwesha   23   40000
# 1   Bhavani   21   35000
# 2  Sreehari   21   30000
# 3    Dileep   22   25000
# 4     Druvi   18   30000

# %%
# Full join
pd.merge(df1,df2,how="outer")
# Out:
#       Names  Age  Salary
# 0   Kishore   24   30000
# 1    Dileep   22   25000
# 2  Sreehari   21   40000
# 3  Upendhar   25   50000
# 4   Anwesha   23   40000
# 5   Bhavani   21   35000
# 6  Sreehari   21   30000
# 7     Druvi   18   30000

# %% [markdown]
# ## Handling Duplicates
# Another important argument for drop_duplicates() is keep, which has three possible options:
#
# first: (default) Drop duplicates except for the first occurrence.
# last: Drop duplicates except for the last occurrence.
# False: Drop all duplicates.
#
# The two main methods that we will use are duplicated() and drop_duplicates().  The former returns a boolean series and the latter can be used to directly delete duplicate rows from a dataframe. For duplicated() method the inputs are:
#
# - keep
#     - "first": Mark duplicates as True except for the first occurrence.
#     - "last": Mark duplicates as True except for the last occurrence.
#     - False: Mark all duplicates as True
#
# For the drop_duplicates() method the keep arguments does the following.
#
# - keep
#     - "first": Drop duplicates except for the first occurrence.
#     - "last": Drop duplicates except for the last occurrence.
#     - False: Drop all duplicates
#
# The second arguments for both is:
#
# - subset: Only consider certain columns for identifying duplicates. If subset is not specific,  by default all of the columns will be used.

# %%
# dup_data = pd.read_csv("Duplicate_data.csv")
# dup_data

# %%
df3 = pd.DataFrame()

# %%
df3['Gender'] = ["Male","Female","Male","Female","Male"]
df3['Married'] = ['yes','no','no','no','yes']
df3['Loan_Status']=['yes','no','no','no','yes']

# %%
#dup_data = dup_data.drop(['Unnamed: 0'],axis=1)

# %%
df3
# Out:
#    Gender Married Loan_Status
# 0    Male     yes         yes
# 1  Female      no          no
# 2    Male      no          no
# 3  Female      no          no
# 4    Male     yes         yes

# %% [markdown]
# ### duplicated()
# ### drop_duplicate()

# %%
df3.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
df3.duplicated(subset=['Gender'])
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
df3.duplicated(subset=['Gender','Married'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
df3.drop_duplicates(keep="first")
# Out:
#    Gender Married Loan_Status
# 0    Male     yes         yes
# 1  Female      no          no
# 2    Male      no          no

# %%
df3.drop_duplicates(keep="last")
# Out:
#    Gender Married Loan_Status
# 2    Male      no          no
# 3  Female      no          no
# 4    Male     yes         yes

# %%
df3.drop_duplicates(keep="first",subset=["Gender"])
# Out:
#    Gender Married Loan_Status
# 0    Male     yes         yes
# 1  Female      no          no

# %%
df3.drop_duplicates(keep="last",subset=["Gender"])
# Out:
#    Gender Married Loan_Status
# 3  Female      no          no
# 4    Male     yes         yes

# %%
df3.drop_duplicates(keep="first",subset=["Gender","Married"])
# Out:
#    Gender Married Loan_Status
# 0    Male     yes         yes
# 1  Female      no          no
# 2    Male      no          no

# %% [markdown]
# ### Selcting sample data

# %%
df.sample(100)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001630    Male      No          0  Not Graduate            No
# 80   LP001947    Male     Yes          0      Graduate            No
# 161  LP002369    Male     Yes          0      Graduate            No
# 376  LP002305  Female      No          0      Graduate            No
# 122  LP002587    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 254  LP001482    Male     Yes          0      Graduate           Yes
# 285  LP002237    Male      No          1      Graduate           NaN
# 147  LP002911    Male     Yes          1      Graduate            No
# 319  LP002798    Male     Yes          0      Graduate            No
# 349  LP001570    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 73              2333        1451.000000       102.0             480.0
# 80              2383        3334.000000       172.0             360.0
# 161             2920          16.120001        87.0             360.0
# 376             4547           0.000000       115.0             360.0
# 122             2600        1700.000000       107.0             360.0
# ..               ...                ...         ...               ...
# 254             3459           0.000000        25.0             120.0
# 285             3667           0.000000       113.0             180.0
# 147             2787        1917.000000       146.0             360.0
# 319             3887        2669.000000       162.0             360.0
# 349             4167        1447.000000       158.0             360.0
#
#      Credit_History Property_Area Loan_Status  New
# 73              0.0         Urban           N  Low
# 80              1.0     Semiurban           Y  Low
# 161             1.0         Rural           Y  Low
# 376             1.0     Semiurban           Y  Low
# 122             1.0         Rural           Y  Low
# ..              ...           ...         ...  ...
# 254             1.0     Semiurban           Y  Low
# 285             1.0         Urban           Y  Low
# 147             0.0         Rural           N  Low
# 319             1.0     Semiurban           Y  Low
# 349             1.0         Rural           Y  Low
#
# [100 rows x 14 columns]

# %%
df.shape
# Out:
# (614, 14)

# %%
df.sample(100,random_state=5)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 504  LP002778    Male     Yes          2      Graduate           Yes
# 52   LP001431  Female      No          0      Graduate            No
# 406  LP002211    Male     Yes          0      Graduate            No
# 561  LP002050    Male     Yes          1      Graduate           Yes
# 424  LP001398    Male      No          0      Graduate           NaN
# ..        ...     ...     ...        ...           ...           ...
# 75   LP002239    Male      No          0  Not Graduate            No
# 250  LP001883  Female      No          0      Graduate           NaN
# 326  LP001698    Male      No          0  Not Graduate            No
# 155  LP002288    Male     Yes          2  Not Graduate            No
# 212  LP002277  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 504             6633                0.0         NaN             360.0
# 52              2137             8980.0       137.0             360.0
# 406             4817              923.0       120.0             180.0
# 561            10000                0.0       155.0             360.0
# 424             5050                0.0       118.0             360.0
# ..               ...                ...         ...               ...
# 75              2346             1600.0       132.0             360.0
# 250             3418                0.0       135.0             360.0
# 326             3975             2531.0        55.0             360.0
# 155             2889                0.0        45.0             180.0
# 212             3180                0.0        71.0             360.0
#
#      Credit_History Property_Area Loan_Status     New
# 504             0.0         Rural           N  Medium
# 52              0.0     Semiurban           Y     Low
# 406             1.0         Urban           Y     Low
# 561             1.0         Rural           N  Medium
# 424             1.0     Semiurban           Y     Low
# ..              ...           ...         ...     ...
# 75              1.0     Semiurban           Y     Low
# 250             1.0         Rural           N     Low
# 326             1.0         Rural           Y     Low
# 155             0.0         Urban           N     Low
# 212             0.0         Urban           N     Low
#
# [100 rows x 14 columns]

# %%
a = df.sample(100,random_state=5,ignore_index=True)
a
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP002778    Male     Yes          2      Graduate           Yes
# 1   LP001431  Female      No          0      Graduate            No
# 2   LP002211    Male     Yes          0      Graduate            No
# 3   LP002050    Male     Yes          1      Graduate           Yes
# 4   LP001398    Male      No          0      Graduate           NaN
# ..       ...     ...     ...        ...           ...           ...
# 95  LP002239    Male      No          0  Not Graduate            No
# 96  LP001883  Female      No          0      Graduate           NaN
# 97  LP001698    Male      No          0  Not Graduate            No
# 98  LP002288    Male     Yes          2  Not Graduate            No
# 99  LP002277  Female      No          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              6633                0.0         NaN             360.0
# 1              2137             8980.0       137.0             360.0
# 2              4817              923.0       120.0             180.0
# 3             10000                0.0       155.0             360.0
# 4              5050                0.0       118.0             360.0
# ..              ...                ...         ...               ...
# 95             2346             1600.0       132.0             360.0
# 96             3418                0.0       135.0             360.0
# 97             3975             2531.0        55.0             360.0
# 98             2889                0.0        45.0             180.0
# 99             3180                0.0        71.0             360.0
#
#     Credit_History Property_Area Loan_Status     New
# 0              0.0         Rural           N  Medium
# 1              0.0     Semiurban           Y     Low
# 2              1.0         Urban           Y     Low
# 3              1.0         Rural           N  Medium
# 4              1.0     Semiurban           Y     Low
# ..             ...           ...         ...     ...
# 95             1.0     Semiurban           Y     Low
# 96             1.0         Rural           N     Low
# 97             1.0         Rural           Y     Low
# 98             0.0         Urban           N     Low
# 99             0.0         Urban           N     Low
#
# [100 rows x 14 columns]

# %% [markdown]
# ### Saving data into local directory

# %%
a.to_csv("result.csv")

# %%
a.to_excel("result2.xlsx")

# %%
#a.to_csv("D:\\sample\\result.csv")
