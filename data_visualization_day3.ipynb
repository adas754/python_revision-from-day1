# %% [markdown]
# ##### import tips dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### 1. Write a Python program to display a bar chart of the total bill of Gender and write the intuition about the plot.

# %%
### code here
sns.barplot(x='sex',y='total_bill',data=df)
plt.title('Total by a Gender')
plt.xlabel('Gender')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# ###### 2. Write a Python program to display a box plot of the total bill of day and hue = "smoker" and write the intuition about the plot.

# %%
#### code here
sns.boxplot(x="day",y="total_bill",hue="smoker",data=df)
plt.title('Total Bill by day and smoker')
plt.xlabel('Day')
plt.ylabel('Total bill')
plt.show()

# %% [markdown]
# ##### 3. Write a Python program to display a violin plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here
sns.violinplot(x='day',y='total_bill',hue='sex',data=df)
plt.title('Total bill by Gender and day')
plt.xlabel('Day')
plt.ylabel("Total bill")
plt.show()

# %%
sns.violinplot(y='day',x='total_bill',hue='sex',data=df)
plt.title('Total bill by Gender and day')
plt.xlabel('total bill')
plt.ylabel("day")
plt.show()

# %% [markdown]
# ##### 4. Write a Python program to display a strip plot of the total bill of Day and hue = "sex" and write the intuition about the plot.

# %%
### code here 
sns.stripplot(x='day',y='total_bill',hue='sex',data=df)
plt.title('Total bill by Gender and total day')
plt.xlabel('Day')
plt.ylabel('Total bill')
plt.show()

# %% [markdown]
# ##### 5. Write a Python program to display heat map of dataframe and write the intuition about the plot.

# %%
### code here
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of tips dataset')
plt.show()
# Out:
# <ipython-input-14-eed84cc131c6>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ##### 6. Write a Python program to display scatter plot of total bill of tip and write the intuition about the plot.

# %%
### code here
sns.scatterplot(x='total_bill',y='tip',data=df)
plt.title('Scatter plot of total bill vs tip')
plt.show()

# %% [markdown]
# ##### 7. Write a Python program to display density plot of all numerical columns from the dataframe and write the intution about plot.

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
### code here
numerical_cols=['total_bill','tip','size']
for col in numerical_cols:
  sns.kdeplot(data=df[col],shade=True)
# Out:
# <ipython-input-17-a07a7ee69887>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[col],shade=True)
# <ipython-input-17-a07a7ee69887>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[col],shade=True)
# <ipython-input-17-a07a7ee69887>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df[col],shade=True)

# %% [markdown]
# ##### 8. Write a Python program to calculate average total bills by days and display top 4 days by plot.

# %%
avg_total_by_day=df.groupby('day')['total_bill'].mean().sort_values(ascending=False)
top_4_days=avg_total_by_day.index[:4]
top_4_tips=df[df['day'].isin(top_4_days)]
sns.catplot(x='day',y='total_bill',data=top_4_tips,kind='bar',order=top_4_days)
plt.title('Average total bill by day')
plt.xlabel('Day')
plt.ylabel('Average total bill')
plt.show()

# %% [markdown]
# #### Bonus Question

# %% [markdown]
# ###### 1. What is Histogram chart ?

# %% [markdown]
# # A histogram is a chart that groups numeric data into bins,displaying bin as segmented columns

# %% [markdown]
# ##### 2. What is box plot ?

# %% [markdown]
# # A box plot displays a box that spans the InterQuartile range(IQR) of the data,with a vertical line inside box indicating median.

# %% [markdown]
# ##### 3. What are the plots we can use for univeriate analysis.

# %% [markdown]
# ##univeriate analysis used to analyze one variable at a time

# %% [markdown]
# ##### 4. What are the plots we can use for bivariate analysis.

# %% [markdown]
# # Bivariate Analysis Relationship between two variable

# %% [markdown]
# ###### 5. What are plot we can use for multivariate analysis.

# %% [markdown]
# ##used to analyze the relationship between three or more variable.
