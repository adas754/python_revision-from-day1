# %%
import pandas as pd
df=pd.read_csv('/content/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.rename(columns={'SepalLengthCm':"SepLen"},inplace=True)

# %%
df
# Out:
#       Id  SepLen  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1     5.1           3.5            1.4           0.2     Iris-setosa
# 1      2     4.9           3.0            1.4           0.2     Iris-setosa
# 2      3     4.7           3.2            1.3           0.2     Iris-setosa
# 3      4     4.6           3.1            1.5           0.2     Iris-setosa
# 4      5     5.0           3.6            1.4           0.2     Iris-setosa
# ..   ...     ...           ...            ...           ...             ...
# 145  146     6.7           3.0            5.2           2.3  Iris-virginica
# 146  147     6.3           2.5            5.0           1.9  Iris-virginica
# 147  148     6.5           3.0            5.2           2.0  Iris-virginica
# 148  149     6.2           3.4            5.4           2.3  Iris-virginica
# 149  150     5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.rename(columns={'SepalWidthCm':'SepWid','PetalLengthCm':'PetLen','PetalWidthCm':'PetWid'},inplace=True)

# %%
df
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 0      1     5.1     3.5     1.4     0.2     Iris-setosa
# 1      2     4.9     3.0     1.4     0.2     Iris-setosa
# 2      3     4.7     3.2     1.3     0.2     Iris-setosa
# 3      4     4.6     3.1     1.5     0.2     Iris-setosa
# 4      5     5.0     3.6     1.4     0.2     Iris-setosa
# ..   ...     ...     ...     ...     ...             ...
# 145  146     6.7     3.0     5.2     2.3  Iris-virginica
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 147  148     6.5     3.0     5.2     2.0  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'].nunique()
# Out:
# 3

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df['SepLen'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df['SepLen'].nunique()
# Out:
# 35

# %%
df.SepLen.value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepLen, dtype: int64

# %%
df['Species']=='Iris-setosa'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Species, Length: 150, dtype: bool

# %%
setosa=df[df['Species']=='Iris-setosa']
setosa
# Out:
#     Id  SepLen  SepWid  PetLen  PetWid      Species
# 0    1     5.1     3.5     1.4     0.2  Iris-setosa
# 1    2     4.9     3.0     1.4     0.2  Iris-setosa
# 2    3     4.7     3.2     1.3     0.2  Iris-setosa
# 3    4     4.6     3.1     1.5     0.2  Iris-setosa
# 4    5     5.0     3.6     1.4     0.2  Iris-setosa
# 5    6     5.4     3.9     1.7     0.4  Iris-setosa
# 6    7     4.6     3.4     1.4     0.3  Iris-setosa
# 7    8     5.0     3.4     1.5     0.2  Iris-setosa
# 8    9     4.4     2.9     1.4     0.2  Iris-setosa
# 9   10     4.9     3.1     1.5     0.1  Iris-setosa
# 10  11     5.4     3.7     1.5     0.2  Iris-setosa
# 11  12     4.8     3.4     1.6     0.2  Iris-setosa
# 12  13     4.8     3.0     1.4     0.1  Iris-setosa
# 13  14     4.3     3.0     1.1     0.1  Iris-setosa
# 14  15     5.8     4.0     1.2     0.2  Iris-setosa
# 15  16     5.7     4.4     1.5     0.4  Iris-setosa
# 16  17     5.4     3.9     1.3     0.4  Iris-setosa
# ...

# %%
setosa.shape
# Out:
# (50, 6)

# %%
df.describe()
# Out:
#                Id      SepLen      SepWid      PetLen      PetWid
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean    75.500000    5.843333    3.054000    3.758667    1.198667
# std     43.445368    0.828066    0.433594    1.764420    0.763161
# min      1.000000    4.300000    2.000000    1.000000    0.100000
# 25%     38.250000    5.100000    2.800000    1.600000    0.300000
# 50%     75.500000    5.800000    3.000000    4.350000    1.300000
# 75%    112.750000    6.400000    3.300000    5.100000    1.800000
# max    150.000000    7.900000    4.400000    6.900000    2.500000

# %%
df.describe(include='object')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df["SepLen"].min()
# Out:
# 4.3

# %%
df["SepLen"].max()
# Out:
# 7.9

# %%
df["SepLen"].mean()
# Out:
# 5.843333333333334

# %%
df["SepLen"].mode()
# Out:
# 0    5.0
# Name: SepLen, dtype: float64

# %%
df["SepLen"].median()
# Out:
# 5.8

# %%
df['Species'].mode()
# Out:
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# Name: Species, dtype: object

# %%
df['SepLen'].mean()
# Out:
# 5.843333333333334

# %%
df["SepLen"]>5.843333333333335
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: SepLen, Length: 150, dtype: bool

# %%
len(df[df['SepLen']>5.843333333333335])
# Out:
# 70

# %%
len(df[df['SepLen']>df['SepLen'].mean()])
# Out:
# 70

# %%
df.quantile(0.25)
# Out:
# <ipython-input-33-29e18f3a7353>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.quantile(0.25)
# Id        38.25
# SepLen     5.10
# SepWid     2.80
# PetLen     1.60
# PetWid     0.30
# Name: 0.25, dtype: float64

# %%
df['SepLen'].quantile(0.25)
# Out:
# 5.1

# %%
df['SepLen'].quantile(0.75)
# Out:
# 6.4

# %%
df['SepLen']>5.1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: SepLen, Length: 150, dtype: bool

# %%
df[(df['SepLen']>5.1) & (df['SepLen']<6.4)]
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 5      6     5.4     3.9     1.7     0.4     Iris-setosa
# 10    11     5.4     3.7     1.5     0.2     Iris-setosa
# 14    15     5.8     4.0     1.2     0.2     Iris-setosa
# 15    16     5.7     4.4     1.5     0.4     Iris-setosa
# 16    17     5.4     3.9     1.3     0.4     Iris-setosa
# ..   ...     ...     ...     ...     ...             ...
# 138  139     6.0     3.0     4.8     1.8  Iris-virginica
# 142  143     5.8     2.7     5.1     1.9  Iris-virginica
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
#
# [67 rows x 6 columns]

# %%
df[(df['SepLen']>df['SepLen'].quantile(0.25)) & (df['SepLen']<df['SepLen'].quantile(0.75))]
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 5      6     5.4     3.9     1.7     0.4     Iris-setosa
# 10    11     5.4     3.7     1.5     0.2     Iris-setosa
# 14    15     5.8     4.0     1.2     0.2     Iris-setosa
# 15    16     5.7     4.4     1.5     0.4     Iris-setosa
# 16    17     5.4     3.9     1.3     0.4     Iris-setosa
# ..   ...     ...     ...     ...     ...             ...
# 138  139     6.0     3.0     4.8     1.8  Iris-virginica
# 142  143     5.8     2.7     5.1     1.9  Iris-virginica
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
#
# [67 rows x 6 columns]

# %%
df
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 0      1     5.1     3.5     1.4     0.2     Iris-setosa
# 1      2     4.9     3.0     1.4     0.2     Iris-setosa
# 2      3     4.7     3.2     1.3     0.2     Iris-setosa
# 3      4     4.6     3.1     1.5     0.2     Iris-setosa
# 4      5     5.0     3.6     1.4     0.2     Iris-setosa
# ..   ...     ...     ...     ...     ...             ...
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 147  148     6.5     3.0     5.2     2.0  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
# 151  151     3.1     4.5     6.0     3.8  Iris-virginica
#
# [151 rows x 6 columns]

# %%
df.loc[151]=[151,3.1,4.5,6.0,3.8,'Iris-virginica']

# %%
df.tail()
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 147  148     6.5     3.0     5.2     2.0  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
# 151  151     3.1     4.5     6.0     3.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 151
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       151 non-null    int64
#  1   SepLen   151 non-null    float64
#  2   SepWid   151 non-null    float64
#  3   PetLen   151 non-null    float64
#  4   PetWid   151 non-null    float64
#  5   Species  151 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
df.tail(10)
# Out:
#       Id  SepLen  SepWid  PetLen  PetWid         Species
# 141  142     6.9     3.1     5.1     2.3  Iris-virginica
# 142  143     5.8     2.7     5.1     1.9  Iris-virginica
# 143  144     6.8     3.2     5.9     2.3  Iris-virginica
# 144  145     6.7     3.3     5.7     2.5  Iris-virginica
# 145  146     6.7     3.0     5.2     2.3  Iris-virginica
# 146  147     6.3     2.5     5.0     1.9  Iris-virginica
# 147  148     6.5     3.0     5.2     2.0  Iris-virginica
# 148  149     6.2     3.4     5.4     2.3  Iris-virginica
# 149  150     5.9     3.0     5.1     1.8  Iris-virginica
# 151  151     3.1     4.5     6.0     3.8  Iris-virginica

# %%
df.loc[152]=[152,"3.1","4.5",6.0,3.8,"Iris-virginica"]

# %%
df.tail()
# Out:
#       Id SepLen SepWid  PetLen  PetWid         Species
# 147  148    6.5    3.0     5.2     2.0  Iris-virginica
# 148  149    6.2    3.4     5.4     2.3  Iris-virginica
# 149  150    5.9    3.0     5.1     1.8  Iris-virginica
# 151  151    3.1    4.5     6.0     3.8  Iris-virginica
# 152  152    3.1    4.5     6.0     3.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       152 non-null    int64
#  1   SepLen   152 non-null    float64
#  2   SepWid   152 non-null    object
#  3   PetLen   152 non-null    float64
#  4   PetWid   152 non-null    float64
#  5   Species  152 non-null    object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 8.3+ KB

# %%
df['SepLen']=df['SepLen'].astype('float')

# %%
df
# Out:
#       Id  SepLen SepWid  PetLen  PetWid         Species
# 0      1     5.1    3.5     1.4     0.2     Iris-setosa
# 1      2     4.9    3.0     1.4     0.2     Iris-setosa
# 2      3     4.7    3.2     1.3     0.2     Iris-setosa
# 3      4     4.6    3.1     1.5     0.2     Iris-setosa
# 4      5     5.0    3.6     1.4     0.2     Iris-setosa
# ..   ...     ...    ...     ...     ...             ...
# 147  148     6.5    3.0     5.2     2.0  Iris-virginica
# 148  149     6.2    3.4     5.4     2.3  Iris-virginica
# 149  150     5.9    3.0     5.1     1.8  Iris-virginica
# 151  151     3.1    4.5     6.0     3.8  Iris-virginica
# 152  152     3.1    4.5     6.0     3.8  Iris-virginica
#
# [152 rows x 6 columns]

# %%
df['SepWid']=df['SepWid'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       152 non-null    int64
#  1   SepLen   152 non-null    float64
#  2   SepWid   152 non-null    float64
#  3   PetLen   152 non-null    float64
#  4   PetWid   152 non-null    float64
#  5   Species  152 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.3+ KB
