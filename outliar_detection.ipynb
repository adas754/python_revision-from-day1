# %%
import pandas as pd
df=pd.read_csv('/content/loandata.csv')
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df['Gender']=df['Gender'].replace({'Male':1,'Female':0})
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722     1.0     Yes          0      Graduate            No
# 1    LP002502     0.0     Yes          2  Not Graduate           NaN
# 2    LP002949     0.0      No         3+      Graduate           NaN
# 3    LP002603     0.0      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640     1.0     Yes          0      Graduate           Yes
# 610  LP001536     1.0     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101     1.0     Yes          0      Graduate           NaN
# 613  LP002317     1.0     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Married']=df['Married'].replace({'Yes':1,'No':0})

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0    LP001722     1.0      1.0          0      Graduate            No
# 1    LP002502     0.0      1.0          2  Not Graduate           NaN
# 2    LP002949     0.0      0.0         3+      Graduate           NaN
# 3    LP002603     0.0      0.0          0      Graduate            No
# 4    LP001644     NaN      1.0          0      Graduate           Yes
# ..        ...     ...      ...        ...           ...           ...
# 609  LP001640     1.0      1.0          0      Graduate           Yes
# 610  LP001536     1.0      1.0         3+      Graduate            No
# 611  LP001585     NaN      1.0         3+      Graduate            No
# 612  LP002101     1.0      1.0          0      Graduate           NaN
# 613  LP002317     1.0      1.0         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.loc[df['ApplicantIncome']<=5000,'ApplicantIncome']+=10000

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0    LP001722     1.0      1.0          0      Graduate            No
# 1    LP002502     0.0      1.0          2  Not Graduate           NaN
# 2    LP002949     0.0      0.0         3+      Graduate           NaN
# 3    LP002603     0.0      0.0          0      Graduate            No
# 4    LP001644     NaN      1.0          0      Graduate           Yes
# ..        ...     ...      ...        ...           ...           ...
# 609  LP001640     1.0      1.0          0      Graduate           Yes
# 610  LP001536     1.0      1.0         3+      Graduate            No
# 611  LP001585     NaN      1.0         3+      Graduate            No
# 612  LP002101     1.0      1.0          0      Graduate           NaN
# 613  LP002317     1.0      1.0         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['ApplicantIncome']
# Out:
# 0        150
# 1        210
# 2        416
# 3        645
# 4        674
#        ...
# 609    39147
# 610    39999
# 611    51763
# 612    63337
# 613    81000
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['ApplicantIncome'].min(),df['ApplicantIncome'].max(),df['ApplicantIncome'].mean()
# Out:
# (150, 81000, 5403.459283387622)

# %%
Q1=df['ApplicantIncome'].quantile(0.25)
Q2=df['ApplicantIncome'].quantile(0.5)
Q3=df['ApplicantIncome'].quantile(0.75)

# %%
Q1,Q2,Q3
# Out:
# (2877.5, 3812.5, 5795.0)

# %%
df['ApplicantIncome'].median()
# Out:
# 3812.5

# %%
IQR=Q3-Q1

# %%
low_boundary=Q1-(1.5*IQR)
low_boundary
# Out:
# -1498.75

# %%
upper_boundary=Q3+(1.5*IQR)
upper_boundary
# Out:
# 10171.25

# %%
df[df['ApplicantIncome']<low_boundary]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df[df['ApplicantIncome']>upper_boundary]

# %%
len(df[df['ApplicantIncome']>upper_boundary])
# Out:
# 50

# %%
df[(df['ApplicantIncome']<low_boundary)|(df['ApplicantIncome']>upper_boundary)]

# %%
len(df[(df['ApplicantIncome']<low_boundary)|(df['ApplicantIncome']>upper_boundary)])
# Out:
# 50

# %% [markdown]
# #Removing Outliar

# %%
len(df[(df['ApplicantIncome']>low_boundary)&(df['ApplicantIncome']<upper_boundary)])
# Out:
# 564

# %%
614-50
# Out:
# 564

# %%
len(df[~((df['ApplicantIncome']<low_boundary)|(df['ApplicantIncome']>upper_boundary))])
# Out:
# 564

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
