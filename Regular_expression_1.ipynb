# %%
text='Innomatics ### is one of the &&& best institute for data Science ???????'

# %% [markdown]
# ##Remove #, ?,  &

# %%
import re
re.sub('[#?&]','',text)
# Out:
# 'Innomatics  is one of the  best institute for data Science '

# %% [markdown]
# \w - Alphanumeric
#
# \W- Special character
#
# \d - number\digits
#
# \s - Space
#
# \b- boundary

# %%
text="""
Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. 
Its high-level built in data structures, combined with dynamic typing and dynamic binding, 
make it very attractive for Rapid Application Development, 
as well as for use as a scripting or glue language to connect existing components together.
Python's simple, easy to learn syntax emphasizes readability and therefore reduces 
the cost of program maintenance. Python supports modules and packages, 
which encourages program modularity and code reuse. 
The Python interpreter and the extensive standard library are available in source or binary form without charge 
for all major platforms, and can be freely distributed.

"""

# %%
re.findall('\w',text) #extract word part by part
# Out:
# ['P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'i',
#  's',
#  'a',
#  'n',
#  'i',
#  'n',
#  't',
#  'e',
#  'r',
#  'p',
#  'r',
#  'e',
#  't',
#  'e',
#  'd',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  'o',
#  'r',
#  'i',
#  'e',
#  'n',
#  't',
#  'e',
#  'd',
#  'h',
#  'i',
#  'g',
#  'h',
#  'l',
#  'e',
#  'v',
#  'e',
#  'l',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  'l',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  'w',
#  'i',
#  't',
#  'h',
#  'd',
#  'y',
#  'n',
#  'a',
#  'm',
#  'i',
#  'c',
#  's',
#  'e',
#  'm',
#  'a',
#  'n',
#  't',
#  'i',
#  'c',
#  's',
#  'I',
#  't',
#  's',
#  'h',
#  'i',
#  'g',
#  'h',
#  'l',
#  'e',
#  'v',
#  'e',
#  'l',
#  'b',
#  'u',
#  'i',
#  'l',
#  't',
#  'i',
#  'n',
#  'd',
#  'a',
#  't',
#  'a',
#  's',
#  't',
#  'r',
#  'u',
#  'c',
#  't',
#  'u',
#  'r',
#  'e',
#  's',
#  'c',
#  'o',
#  'm',
#  'b',
#  'i',
#  'n',
#  'e',
#  'd',
#  'w',
# ...

# %%
print(re.findall('\w\w',text)) #extract first two words
# Out:
# ['Py', 'th', 'on', 'is', 'an', 'in', 'te', 'rp', 're', 'te', 'ob', 'je', 'ct', 'or', 'ie', 'nt', 'ed', 'hi', 'gh', 'le', 've', 'pr', 'og', 'ra', 'mm', 'in', 'la', 'ng', 'ua', 'ge', 'wi', 'th', 'dy', 'na', 'mi', 'se', 'ma', 'nt', 'ic', 'It', 'hi', 'gh', 'le', 've', 'bu', 'il', 'in', 'da', 'ta', 'st', 'ru', 'ct', 'ur', 'es', 'co', 'mb', 'in', 'ed', 'wi', 'th', 'dy', 'na', 'mi', 'ty', 'pi', 'ng', 'an', 'dy', 'na', 'mi', 'bi', 'nd', 'in', 'ma', 'ke', 'it', 've', 'ry', 'at', 'tr', 'ac', 'ti', 've', 'fo', 'Ra', 'pi', 'Ap', 'pl', 'ic', 'at', 'io', 'De', 've', 'lo', 'pm', 'en', 'as', 'we', 'll', 'as', 'fo', 'us', 'as', 'sc', 'ri', 'pt', 'in', 'or', 'gl', 'ue', 'la', 'ng', 'ua', 'ge', 'to', 'co', 'nn', 'ec', 'ex', 'is', 'ti', 'ng', 'co', 'mp', 'on', 'en', 'ts', 'to', 'ge', 'th', 'er', 'Py', 'th', 'on', 'si', 'mp', 'le', 'ea', 'sy', 'to', 'le', 'ar', 'sy', 'nt', 'ax', 'em', 'ph', 'as', 'iz', 'es', 're', 'ad', 'ab', 'il', 'it', 'an', 'th', 'er', 'ef', 'or', 're', 'du', 'ce', 'th', 'co', 'st', '
# ...

# %%
print(re.findall('\w\w\w',text)) #extract three words
# Out:
# ['Pyt', 'hon', 'int', 'erp', 'ret', 'obj', 'ect', 'ori', 'ent', 'hig', 'lev', 'pro', 'gra', 'mmi', 'lan', 'gua', 'wit', 'dyn', 'ami', 'sem', 'ant', 'ics', 'Its', 'hig', 'lev', 'bui', 'dat', 'str', 'uct', 'ure', 'com', 'bin', 'wit', 'dyn', 'ami', 'typ', 'ing', 'and', 'dyn', 'ami', 'bin', 'din', 'mak', 'ver', 'att', 'rac', 'tiv', 'for', 'Rap', 'App', 'lic', 'ati', 'Dev', 'elo', 'pme', 'wel', 'for', 'use', 'scr', 'ipt', 'ing', 'glu', 'lan', 'gua', 'con', 'nec', 'exi', 'sti', 'com', 'pon', 'ent', 'tog', 'eth', 'Pyt', 'hon', 'sim', 'ple', 'eas', 'lea', 'syn', 'tax', 'emp', 'has', 'ize', 'rea', 'dab', 'ili', 'and', 'the', 'ref', 'ore', 'red', 'uce', 'the', 'cos', 'pro', 'gra', 'mai', 'nte', 'nan', 'Pyt', 'hon', 'sup', 'por', 'mod', 'ule', 'and', 'pac', 'kag', 'whi', 'enc', 'our', 'age', 'pro', 'gra', 'mod', 'ula', 'rit', 'and', 'cod', 'reu', 'The', 'Pyt', 'hon', 'int', 'erp', 'ret', 'and', 'the', 'ext', 'ens', 'ive', 'sta', 'nda', 'lib', 'rar', 'are', 'ava', 'ila', 'ble', 'sou', 'rce', 'bi
# ...

# %%
print(re.findall('\w+',text))#extract word by word
# Out:
# ['Python', 'is', 'an', 'interpreted', 'object', 'oriented', 'high', 'level', 'programming', 'language', 'with', 'dynamic', 'semantics', 'Its', 'high', 'level', 'built', 'in', 'data', 'structures', 'combined', 'with', 'dynamic', 'typing', 'and', 'dynamic', 'binding', 'make', 'it', 'very', 'attractive', 'for', 'Rapid', 'Application', 'Development', 'as', 'well', 'as', 'for', 'use', 'as', 'a', 'scripting', 'or', 'glue', 'language', 'to', 'connect', 'existing', 'components', 'together', 'Python', 's', 'simple', 'easy', 'to', 'learn', 'syntax', 'emphasizes', 'readability', 'and', 'therefore', 'reduces', 'the', 'cost', 'of', 'program', 'maintenance', 'Python', 'supports', 'modules', 'and', 'packages', 'which', 'encourages', 'program', 'modularity', 'and', 'code', 'reuse', 'The', 'Python', 'interpreter', 'and', 'the', 'extensive', 'standard', 'library', 'are', 'available', 'in', 'source', 'or', 'binary', 'form', 'without', 'charge', 'for', 'all', 'major', 'platforms', 'and', 'can', 'be', 'f
# ...

# %%
print(re.findall('\w*',text)) #extract word by word with ''
# Out:
# ['', 'Python', '', 'is', '', 'an', '', 'interpreted', '', '1234', '', '', 'object', '', 'oriented', '', '', 'high', '', 'level', '', 'programming', '', 'language', '', 'with', '', 'dynamic', '', 'semantics', '', '', '', 'Its', '', 'high', '', 'level', '', 'built', '', 'in', '', 'data', '', 'structures', '', '', 'combined', '', 'with', '', 'dynamic', '', 'typing', '', 'and', '', 'dynamic', '', 'binding', '', '', '', 'make', '', 'it', '', 'very', '', 'attractive', '', 'for', '', 'Rapid', '', 'Application', '', 'Development', '', '', '', 'as', '', 'well', '', 'as', '', 'for', '', 'use', '', 'as', '', 'a', '', 'scripting', '', 'or', '', 'glue', '', 'language', '', 'to', '', 'connect', '', 'existing', '', 'components', '', 'together', '', '5678', '', '', 'Python', '', 's', '', 'simple', '', '', 'easy', '', 'to', '', 'learn', '', 'syntax', '', 'emphasizes', '', 'readability', '', 'and', '', 'therefore', '', 'reduces', '', '', 'the', '', 'cost', '', 'of', '', 'program', '', 'maintenance', '
# ...

# %%
text="""
Python is an interpreted 1234, object-oriented, high-level programming language with dynamic semantics. 
Its high-level built in data structures, combined with dynamic typing and dynamic binding, 
make it very attractive for Rapid Application Development, 
as well as for use as a scripting or glue language to connect existing components together 5678.
Python's simple, easy to learn syntax emphasizes readability and therefore reduces 
the cost of program maintenance. Python supports modules and packages, 
which encourages program modularity and code reuse. 
The Python interpreter and the extensive standard library are available in source or binary form without charge 
for all major platforms, and can be freely distributed.

"""

# %%
re.findall('\d',text) #extract numeric
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8']

# %%
re.findall('\d+',text)
# Out:
# ['1234', '5678']

# %%
re.findall('\W',text)#special characters
# Out:
# ['\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '-',
#  ',',
#  ' ',
#  '-',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  '\n',
#  ' ',
#  '-',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '\n',
#  "'",
#  ' ',
#  ',',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ',',
#  ' ',
# ...

# %%
re.findall('.',text) # After each word ''
# Out:
# ['P',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  'n',
#  ' ',
#  'i',
#  'n',
#  't',
#  'e',
#  'r',
#  'p',
#  'r',
#  'e',
#  't',
#  'e',
#  'd',
#  ' ',
#  '1',
#  '2',
#  '3',
#  '4',
#  ',',
#  ' ',
#  'o',
#  'b',
#  'j',
#  'e',
#  'c',
#  't',
#  '-',
#  'o',
#  'r',
#  'i',
#  'e',
#  'n',
#  't',
#  'e',
#  'd',
#  ',',
#  ' ',
#  'h',
#  'i',
#  'g',
#  'h',
#  '-',
#  'l',
#  'e',
#  'v',
#  'e',
#  'l',
#  ' ',
#  'p',
#  'r',
#  'o',
#  'g',
#  'r',
#  'a',
#  'm',
#  'm',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'l',
#  'a',
#  'n',
#  'g',
#  'u',
#  'a',
#  'g',
#  'e',
#  ' ',
#  'w',
#  'i',
#  't',
#  'h',
#  ' ',
#  'd',
#  'y',
#  'n',
#  'a',
#  'm',
#  'i',
#  'c',
#  ' ',
#  's',
#  'e',
#  'm',
#  'a',
#  'n',
#  't',
#  'i',
#  'c',
#  's',
#  '.',
#  ' ',
#  'I',
#  't',
#  's',
#  ' ',
#  'h',
#  'i',
#  'g',
#  'h',
#  '-',
#  'l',
#  'e',
#  'v',
#  'e',
#  'l',
#  ' ',
#  'b',
#  'u',
#  'i',
#  'l',
#  't',
#  ' ',
# ...

# %%
re.findall(r'\b[pP]\w+',text) #start with P/p
# Out:
# ['Python',
#  'programming',
#  'Python',
#  'program',
#  'Python',
#  'packages',
#  'program',
#  'Python',
#  'platforms']

# %%
re.findall(r'\bPython',text)#extract only python
# Out:
# ['Python', 'Python', 'Python', 'Python']

# %%
re.findall(r'\b[aeiouAEIOU]\w+',text)#extract only vowel
# Out:
# ['is',
#  'an',
#  'interpreted',
#  'object',
#  'oriented',
#  'Its',
#  'in',
#  'and',
#  'it',
#  'attractive',
#  'Application',
#  'as',
#  'as',
#  'use',
#  'as',
#  'or',
#  'existing',
#  'easy',
#  'emphasizes',
#  'and',
#  'of',
#  'and',
#  'encourages',
#  'and',
#  'interpreter',
#  'and',
#  'extensive',
#  'are',
#  'available',
#  'in',
#  'or',
#  'all',
#  'and']

# %%
re.findall(r'\b[^aeiouAEIOU\s\W]\w+',text)#extract consonent and digits
# Out:
# ['Python',
#  '1234',
#  'high',
#  'level',
#  'programming',
#  'language',
#  'with',
#  'dynamic',
#  'semantics',
#  'high',
#  'level',
#  'built',
#  'data',
#  'structures',
#  'combined',
#  'with',
#  'dynamic',
#  'typing',
#  'dynamic',
#  'binding',
#  'make',
#  'very',
#  'for',
#  'Rapid',
#  'Development',
#  'well',
#  'for',
#  'scripting',
#  'glue',
#  'language',
#  'to',
#  'connect',
#  'components',
#  'together',
#  '5678',
#  'Python',
#  'simple',
#  'to',
#  'learn',
#  'syntax',
#  'readability',
#  'therefore',
#  'reduces',
#  'the',
#  'cost',
#  'program',
#  'maintenance',
#  'Python',
#  'supports',
#  'modules',
#  'packages',
#  'which',
#  'program',
#  'modularity',
#  'code',
#  'reuse',
#  'The',
#  'Python',
#  'the',
#  'standard',
#  'library',
#  'source',
#  'binary',
#  'form',
#  'without',
#  'charge',
#  'for',
#  'major',
#  'platforms',
#  'can',
#  'be',
#  'freely',
#  'distributed']

# %%
re.findall(r'\b[^\d\s\W]\w+',text)#extract only character
# Out:
# ['Python',
#  'is',
#  'an',
#  'interpreted',
#  'object',
#  'oriented',
#  'high',
#  'level',
#  'programming',
#  'language',
#  'with',
#  'dynamic',
#  'semantics',
#  'Its',
#  'high',
#  'level',
#  'built',
#  'in',
#  'data',
#  'structures',
#  'combined',
#  'with',
#  'dynamic',
#  'typing',
#  'and',
#  'dynamic',
#  'binding',
#  'make',
#  'it',
#  'very',
#  'attractive',
#  'for',
#  'Rapid',
#  'Application',
#  'Development',
#  'as',
#  'well',
#  'as',
#  'for',
#  'use',
#  'as',
#  'scripting',
#  'or',
#  'glue',
#  'language',
#  'to',
#  'connect',
#  'existing',
#  'components',
#  'together',
#  'Python',
#  'simple',
#  'easy',
#  'to',
#  'learn',
#  'syntax',
#  'emphasizes',
#  'readability',
#  'and',
#  'therefore',
#  'reduces',
#  'the',
#  'cost',
#  'of',
#  'program',
#  'maintenance',
#  'Python',
#  'supports',
#  'modules',
#  'and',
#  'packages',
#  'which',
#  'encourages',
#  'program',
#  'modularity',
#  'and',
#  'code',
#  'reuse',
# ...

# %%
re.findall(r'\b[a-zA-Z]\w+',text) #extract characters
# Out:
# ['Python',
#  'is',
#  'an',
#  'interpreted',
#  'object',
#  'oriented',
#  'high',
#  'level',
#  'programming',
#  'language',
#  'with',
#  'dynamic',
#  'semantics',
#  'Its',
#  'high',
#  'level',
#  'built',
#  'in',
#  'data',
#  'structures',
#  'combined',
#  'with',
#  'dynamic',
#  'typing',
#  'and',
#  'dynamic',
#  'binding',
#  'make',
#  'it',
#  'very',
#  'attractive',
#  'for',
#  'Rapid',
#  'Application',
#  'Development',
#  'as',
#  'well',
#  'as',
#  'for',
#  'use',
#  'as',
#  'scripting',
#  'or',
#  'glue',
#  'language',
#  'to',
#  'connect',
#  'existing',
#  'components',
#  'together',
#  'Python',
#  'simple',
#  'easy',
#  'to',
#  'learn',
#  'syntax',
#  'emphasizes',
#  'readability',
#  'and',
#  'therefore',
#  'reduces',
#  'the',
#  'cost',
#  'of',
#  'program',
#  'maintenance',
#  'Python',
#  'supports',
#  'modules',
#  'and',
#  'packages',
#  'which',
#  'encourages',
#  'program',
#  'modularity',
#  'and',
#  'code',
#  'reuse',
# ...

# %%
mail='my mail id is adas@gmail.com and a@das@gmail@com'

# %%
re.findall(r'\w+@\w+\.\w+',mail)#extract real mail id
# Out:
# ['adas@gmail.com']

# %%
a=123
re.findall('2',str(a))
# Out:
# ['2']
